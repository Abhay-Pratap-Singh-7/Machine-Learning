# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Ads_CTR_Optimisation.csv')

# %%
N = 100000
d = 10
ads_sel = []
number_of_selection = [0] * d
sums_of_rewards = [0] * d
total_reward = 0
for n in range(0, N):
